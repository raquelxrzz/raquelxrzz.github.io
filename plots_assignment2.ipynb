# %%
# CODE FOR THE VISUALIZATIONS

# Matplotlib for static charts
import matplotlib.pyplot as plt

PRIMARY = "#16c79a"
TEXT = "#1f2430"
GRID = "#e6e9f0"

fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(x, y, color=PRIMARY, linewidth=2.5)

ax.set_title("Your title", fontsize=15, color=TEXT, pad=14)
ax.set_xlabel("Year", color=TEXT)
ax.set_ylabel("Incidents", color=TEXT)

ax.grid(True, color=GRID, linewidth=0.8)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#cfd6e4")
ax.spines["bottom"].set_color("#cfd6e4")
ax.tick_params(colors=TEXT)

plt.tight_layout()
plt.savefig("your_static_plot.png", dpi=150, bbox_inches="tight")

# Plotly for interactive charts
import plotly.express as px

color_continuous_scale = [
    [0.0, "#e8faf5"],
    [0.2, "#bff0e1"],
    [0.4, "#7edfc5"],
    [0.6, "#38cfa7"],
    [0.8, "#16c79a"],
    [1.0, "#0f8f73"]
]

fig.update_layout(
    font=dict(family="Arial", color="#1f2430"),
    paper_bgcolor="white",
    margin=dict(l=0, r=0, t=50, b=0)
)

# Interactive plotly chart
fig.update_layout(
    font=dict(family="Arial", color="#1f2430"),
    paper_bgcolor="white",
    plot_bgcolor="white",
    title=dict(font=dict(size=20)),
    margin=dict(l=40, r=40, t=60, b=40)
)

fig.update_traces(line=dict(color="#16c79a", width=3))
